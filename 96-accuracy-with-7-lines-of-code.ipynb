# %% [markdown]
# Firstly, FastAI is an amazing library and it is quite underestimated. Its not shiny, its not too much code, its the perfect library for doing anything remotely related to computer vision.
# Secondly, LITTLE CODING required. Its way less than other libraries and even though just like pytorch, FastAI is also quite tweakable its main usefulness lies in the default setting which are optimized for almost anything.

# %%
# Importing from the Libary:
from fastai.vision import *
from fastai.metrics import *

# %%
# Here's the path for our file:
path = "../input/bee-vs-wasp/kaggle_bee_vs_wasp"

# Defining the Data:
data = ImageDataBunch.from_folder(path, ds_tfms = get_transforms(), valid_pct = 0.1, size = 512, bs = 8)

# %%
# Visualizing:
data.show_batch(row = 3)

# %%
# Building the model through transfer learning:
model = cnn_learner(data, models.densenet121, metrics = accuracy ,model_dir = "/tmp/model/")
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/checkpoints/densenet121-a639ec97.pth
# HBox(children=(FloatProgress(value=0.0, max=32342954.0), HTML(value='')))

# %%
# Training the model:
model.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.478249</td>
#       <td>0.263255</td>
#       <td>0.918564</td>
#       <td>08:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.413548</td>
#       <td>0.176279</td>
#       <td>0.931699</td>
#       <td>08:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.261533</td>
#       <td>0.130646</td>
#       <td>0.962347</td>
#       <td>08:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.215481</td>
#       <td>0.107672</td>
#       <td>0.963222</td>
#       <td>08:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.172078</td>
#       <td>0.101691</td>
#       <td>0.964974</td>
#       <td>08:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Lets try to predict now since I am confident that this bad boy won't disappoint me:

img = open_image("../input/bee-vs-wasp/kaggle_bee_vs_wasp/bee1/10007154554_026417cfd0_n.jpg")

# Showing you the image:
img.show()
prediction, idx, probability = model.predict(img)
print("The insect is a", prediction, ". The Probabilty being:", max(probability.numpy()))
# Out:
# The insect is a bee1 . The Probabilty being: 0.985881

# %% [markdown]
# And it did not! Thank you for going through my notebook, I hope you have a wonderful day! :)
